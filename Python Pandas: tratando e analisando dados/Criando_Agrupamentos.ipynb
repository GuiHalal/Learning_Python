# %% [markdown]
# # Relatório de Análise VII

# %%
import pandas as pd
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# ...

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
# bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
# selecao = dados['Bairro'].isin(bairros)
# dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
selecao = dados['Bairro'].isin(dados['Bairro'].unique())
#len(dados['Bairro'].unique())
selecao
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21821    True
# 21822    True
# 21823    True
# 21824    True
# 21825    True
# Name: Bairro, Length: 21826, dtype: bool

# %%
len(dados['Bairro'].drop_duplicates())
# Out:
# 152

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
dados.groupby('Bairro').mean()['IPTU']
# Out:
# Bairro
# Abolição              41.666667
# Alto da Boa Vista    159.333333
# Anchieta               0.000000
# Andaraí               46.680412
# Anil                 228.492958
#                         ...
# Vila Valqueire        87.958333
# Vila da Penha          8.730769
# Vista Alegre           0.000000
# Zumbi                116.000000
# Água Santa            15.444444
# Name: IPTU, Length: 152, dtype: float64

# %%
len(grupo_bairro)
# Out:
# 152

# %%
grupo_bairro

# %%
for bairro, dados in grupo_bairro: 
    print(bairro)
# Out:
# Abolição
# Alto da Boa Vista
# Anchieta
# Andaraí
# Anil
# Arpoador
# Bancários
# Bangu
# Barra da Tijuca
# Barra de Guaratiba
# Benfica
# Bento Ribeiro
# Bonsucesso
# Botafogo
# Braz de Pina
# Cachambi
# Cachamorra
# Cacuia
# Caju
# Camorim
# Campinho
# Campo Grande
# Cascadura
# Catete
# Catumbi
# Cavalcanti
# Centro
# Cidade Jardim
# Cidade Nova
# Cocotá
# Coelho Neto
# Colégio
# Copacabana
# Cordovil
# Cosme Velho
# Cosmos
# Curicica
# Del Castilho
# Encantado
# Engenho Novo
# Engenho da Rainha
# Engenho de Dentro
# Estácio
# Flamengo
# Freguesia (Ilha do Governador)
# Freguesia (Jacarepaguá)
# Fátima
# Gamboa
# Gardênia Azul
# Glória
# Grajaú
# Guadalupe
# Guaratiba
# Gávea
# Higienópolis
# Honório Gurgel
# Humaitá
# Icaraí
# Ilha do Governador
# Inhaúma
# Inhoaíba
# Ipanema
# Irajá
# Itanhangá
# Jabour
# Jacarepaguá
# Jacaré
# Jardim América
# Jardim Botânico
# Jardim Carioca
# Jardim Guanabara
# Jardim Oceânico
# Jardim Sulacap
# Joá
# Lagoa
# Lapa
# Laranjeiras
# ...

# %%
 for bairro, data in grupo_bairro: 
    print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Abolição -> 1195.3333333333333
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 875.0
# Andaraí -> 1464.7113402061855
# Anil -> 2048.8732394366198
# Arpoador -> 12923.916666666666
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.552938130986
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.8695652173913
# Bonsucesso -> 1225.9322033898304
# Botafogo -> 8791.828178694159
# Braz de Pina -> 1115.0
# Cachambi -> 1157.1742424242425
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1037.3333333333333
# Campo Grande -> 1267.71714922049
# Cascadura -> 948.7096774193549
# Catete -> 2267.0625
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.7521865889212
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.4285714285713
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.677004538578
# Cordovil -> 905.5555555555555
# ...

# %%
grupo_bairro['Valor'].mean()
# Out:
# Bairro
# Abolição             1195.333333
# Alto da Boa Vista    3966.666667
# Anchieta              875.000000
# Andaraí              1464.711340
# Anil                 2048.873239
#                         ...
# Vila Valqueire       1769.583333
# Vila da Penha        1260.576923
# Vista Alegre         1114.375000
# Zumbi                2150.000000
# Água Santa            861.111111
# Name: Valor, Length: 152, dtype: float64

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2) # <-> ? PARECEM EQUIVALENTES
# dados.groupby('Bairro').mean().round(2)[['Valor', 'Condominio']]
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %% [markdown]
# ## Estatisticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            15.0  1195.33   425.32   800.0   900.0  1180.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             4.0   875.00   132.29   700.0   812.5   900.0   962.5
# Andaraí             97.0  1464.71   408.11   700.0  1200.0  1400.0  1650.0
# Anil                71.0  2048.87  1523.97   300.0  1100.0  1500.0  2675.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      48.0  1769.58  2203.01   800.0  1000.0  1250.0  1700.0
# Vila da Penha      104.0  1260.58   644.66   450.0   900.0  1100.0  1302.5
# Vista Alegre        16.0  1114.38   199.60   700.0  1012.5  1200.0  1225.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa           9.0   861.11   174.60   600.0   800.0   850.0   950.0
#
#                        max
# Bairro
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum'])
# Out:
#                       min      max       sum
# Bairro
# Abolição            800.0   2300.0   17930.0
# Alto da Boa Vista   600.0  15000.0   23800.0
# Anchieta            700.0   1000.0    3500.0
# Andaraí             700.0   2950.0  142077.0
# Anil                300.0   7000.0  145470.0
# ...                   ...      ...       ...
# Vila Valqueire      800.0  16000.0   84940.0
# Vila da Penha       450.0   4500.0  131100.0
# Vista Alegre        700.0   1400.0   17830.0
# Zumbi              1600.0   2700.0    4300.0
# Água Santa          600.0   1200.0    7750.0
#
# [152 rows x 3 columns]

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo', 'sum' : 'Somatório'})
# Out:
#                    Mínimo   Máximo  Somatório
# Bairro
# Abolição            800.0   2300.0    17930.0
# Alto da Boa Vista   600.0  15000.0    23800.0
# Anchieta            700.0   1000.0     3500.0
# Andaraí             700.0   2950.0   142077.0
# Anil                300.0   7000.0   145470.0
# ...                   ...      ...        ...
# Vila Valqueire      800.0  16000.0    84940.0
# Vila da Penha       450.0   4500.0   131100.0
# Vista Alegre        700.0   1400.0    17830.0
# Zumbi              1600.0   2700.0     4300.0
# Água Santa          600.0   1200.0     7750.0
#
# [152 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (30,15))

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color = 'blue')

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_xlabel('Bairro', {'fontsize': 25})
fig.set_ylabel('Valor do Aluguel', {'fontsize': 25})
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 25})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')
